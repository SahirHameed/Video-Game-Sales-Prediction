# %% [markdown]
# # Video Game Sales Prediction

# %% [markdown]
# ## Part 0: Introduction

# %% [markdown]
# This dataset, inspired by Gregory Smith's web scrape of VGChartz, extends video game sales data with additional variables sourced from Metacritic. It includes information on game sales by region, critic and user scores, and game metadata such as platform, genre, and ESRB ratings.

# %% [markdown]
# ### Objective: To create a classification model that can predict the global sale of a video game (Note the target column in the dataset is Global_Sales)

# %% [markdown]
# We will follow the following steps:
# 1. Read the Data
# 2. Reduce the data by
#    - Removing N/A values
#    - Removing Outliers
# 3. Data Exploration
#    - Looking into the different types of games (consoles, PCs, etc..)
# 4. Feature Engineering
#    - One Hot encoding categorical variables
# 5. Modeling
#    - K Nearest Neighbor
#    - Logistic Regression
#    - Random Forest
#    - Decision Tree

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Reading and Understanding the DataSet

# %%
file_path = "Video_Games_Sales_as_at_22_Dec_2016.csv"
df = pd.read_csv(file_path)

df.shape
# Out:
# (16719, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Features
#
# 1. **Name**: The title of the video game *(Nominal)* – serves as an identifier for each game.
#
# 2. **Platform**: The gaming console or platform for which the game was released *(Nominal)* – e.g., PS4, Xbox, PC.
#
# 3. **Year_of_Release**: The year when the game was released *(Discrete)* – Although recorded as whole numbers, this variable represents a time series trend.
#
# 4. **Genre**: The category or type of the game *(Nominal)* – e.g., Action, Adventure, Sports.
#
# 5. **Publisher**: The company responsible for publishing and distributing the game *(Nominal)* – e.g., Nintendo, EA Sports.
#
# 6. **NA_Sales**: Total sales in millions of units in North America *(Continuous)* – Indicates the success of the game in the North American market.
#
# 7. **EU_Sales**: Total sales in millions of units in Europe *(Continuous)* – Measures the game’s performance in the European market.
#
# 8. **JP_Sales**: Total sales in millions of units in Japan *(Continuous)* – Highlights sales in one of the major gaming markets globally.
#
# 9. **Other_Sales**: Total sales in millions of units in regions other than North America, Europe, and Japan *(Continuous)*.
#
# 10. **Global_Sales**: Total worldwide sales in millions of units *(Continuous)* – The cumulative success of the game globally. **Target Variable**.
#
# 11. **Critic_Score**: Aggregate critic review score, typically out of 100 *(Continuous)* – Reflects the reception of the game by professional critics.
#
# 12. **Critic_Count**: The number of critics who reviewed the game *(Discrete)* – Provides insight into the reliability of the `Critic_Score`.
#
# 13. **User_Score**: The average user rating of the game, typically on a 0–10 scale *(Continuous)* – Reflects public reception of the game.
#
# 14. **User_Count**: The number of users who rated the game *(Discrete)* – Indicates how engaged the audience was.
#
# 15. **Developer**: The company or team that created the game *(Nominal)* – Provides insights into the production and quality of the game.
#
# 16. **Rating**: The ESRB rating assigned to the game *(Nominal)* – Indicates the age group for which the game is suitable, e.g., E (Everyone), T (Teen), M (Mature).

# %% [markdown]
# # Data Preprocessing

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("\nPercentage of missing values per column:")
print(missing_percentage)
# Out:
# Percentage of missing values per column:
# Name                0.011962
# Platform            0.000000
# Year_of_Release     1.608948
# Genre               0.011962
# Publisher           0.322986
# NA_Sales            0.000000
# EU_Sales            0.000000
# JP_Sales            0.000000
# Other_Sales         0.000000
# Global_Sales        0.000000
# Critic_Score       51.330821
# Critic_Count       51.330821
# User_Score         40.098092
# User_Count         54.602548
# Developer          39.613613
# Rating             40.486871
# dtype: float64

# %%
# Visualize the distribution of Critic_Score and User_Score to decide how to fill in the missing values
plt.figure(figsize=(12, 6))
plt.hist(
    df["Critic_Score"].dropna(), bins=30, color="blue", alpha=0.7, label="Critic_Score"
)
plt.hist(
    pd.to_numeric(df["User_Score"], errors="coerce").dropna(),
    bins=30,
    color="orange",
    alpha=0.7,
    label="User_Score",
)
plt.title("Distribution of Critic_Score and User_Score")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# Based on the distribution of data, using the median would be a good choice.

# %%
# Impute missing `Critic_Score` and `User_Score` with the median
df["Critic_Score"] = df["Critic_Score"].fillna(df["Critic_Score"].median())
df["User_Score"] = pd.to_numeric(
    df["User_Score"], errors="coerce"
)  # Convert "tbd" to NaN
df["User_Score"] = df["User_Score"].fillna(df["User_Score"].median())

# Handle categorical `Rating` by filling with the mode
df["Rating"] = df["Rating"].fillna(df["Rating"].mode()[0])

# Verify changes in the dataset
print("\nDataset info after handling missing values and dropping rows:")
df.info()
# Out:
# Dataset info after handling missing values and dropping rows:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     16719 non-null  float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       16719 non-null  float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           16719 non-null  object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %%
# Drop all rows with any missing values
df.dropna(inplace=True)

# Verify the dataset after dropping rows
print("\nDataset info after removing all rows with any missing values:")
df.info()
# Out:
# Dataset info after removing all rows with any missing values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6889 entries, 0 to 16709
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6889 non-null   object
#  1   Platform         6889 non-null   object
#  2   Year_of_Release  6889 non-null   float64
#  3   Genre            6889 non-null   object
#  4   Publisher        6889 non-null   object
#  5   NA_Sales         6889 non-null   float64
#  6   EU_Sales         6889 non-null   float64
#  7   JP_Sales         6889 non-null   float64
#  8   Other_Sales      6889 non-null   float64
#  9   Global_Sales     6889 non-null   float64
#  10  Critic_Score     6889 non-null   float64
#  11  Critic_Count     6889 non-null   float64
#  12  User_Score       6889 non-null   float64
#  13  User_Count       6889 non-null   float64
#  14  Developer        6889 non-null   object
#  15  Rating           6889 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 914.9+ KB

# %%
# List of numerical columns to check for outliers
numerical_columns = ["Critic_Score", "User_Score", "Global_Sales"]

# Generate boxplots for each numerical column
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, start=1):
    if col in df.columns:
        plt.subplot(3, 3, i)  # Create subplots (3 rows x 3 columns for 9 plots)
        plt.boxplot(
            df[col].dropna(),
            vert=False,
            patch_artist=True,
            boxprops=dict(facecolor="skyblue"),
        )
        plt.title(f"Boxplot of {col}")
        plt.xlabel(col)
plt.tight_layout()
plt.show()
df.shape
# Out:
# (6889, 16)

# %%
# Remove outliers for Critic_Score
df = df[(df["Critic_Score"] >= 20) & (df["Critic_Score"] <= 100)]

# Remove outliers for Global_Sales
df = df[df["Global_Sales"] <= 20]

df.shape
# Out:
# (6868, 16)

# %%
categorical_columns = ["Platform", "Genre", "Publisher", "Developer", "Rating"]

for col in categorical_columns:
    print(f"Value counts for {col}:\n")
    print(df[col].value_counts())
    print("\n")
# Out:
# Value counts for Platform:
#
# Platform
# PS2     1139
# X360     858
# PS3      771
# PC       686
# XB       564
# Wii      471
# DS       461
# PSP      390
# GC       348
# PS4      248
# GBA      237
# XOne     165
# 3DS      156
# PS       153
# PSV      118
# WiiU      89
# DC        14
# Name: count, dtype: int64
#
#
# Value counts for Genre:
#
# Genre
# Action          1640
# Sports           943
# Shooter          868
# Role-Playing     715
# Racing           582
# Platform         400
# Misc             382
# Fighting         379
# Simulation       302
# Strategy         277
# Adventure        262
# Puzzle           118
# Name: count, dtype: int64
#
#
# Value counts for Publisher:
#
# Publisher
# Electronic Arts                944
# Ubisoft                        498
# Activision                     492
# Sony Computer Entertainment    316
# THQ                            307
#                               ...
# NDA Productions                  1
# Moss                             1
# Crytek                           1
# Funsta                           1
# NewKidCo                         1
# Name: count, Length: 270, dtype: int64
#
#
# Value counts for Developer:
#
# Developer
# EA Canada                                 149
# EA Sports                                 142
# Capcom                                    126
# Ubisoft                                   103
# Konami                                     97
#                                          ...
# Felistella                                  1
# Netherock Ltd.                              1
# Interchannel                                1
# Warner Bros. Interactive Entertainment      1
# DTP Entertainment                           1
# Name: count, Length: 1301, dtype: int64
#
#
# Value counts for Rating:
#
# Rating
# T       2377
# E       2132
# M       1428
# E10+     928
# AO         1
# K-A        1
# RP         1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

for col in categorical_columns:
    value_counts = df[col].value_counts()
    lowest_frequency = value_counts.min() # Find the lowest frequency
    rare_categories = value_counts[value_counts == lowest_frequency].index
    print(f"Categories in {col} with the lowest frequency ({lowest_frequency}): {list(rare_categories)}\n")
# Out:
# Categories in Platform with the lowest frequency (14): ['DC']
#
# Categories in Genre with the lowest frequency (118): ['Puzzle']
#
# Categories in Publisher with the lowest frequency (1): ['Crimson Cow', 'Team17 Software', 'Visco', 'Max Five', 'id Software', 'Lighthouse Interactive', 'ESP', 'Conspiracy Entertainment', 'CDV Software Entertainment', 'Navarre Corp', 'Encore', 'Dusenberry Martin Racing', 'Phantagram', 'Blue Byte', 'Paradox Development', 'FuRyu Corporation', 'Monte Christo Multimedia', '10TACLE Studios', 'Global A Entertainment', 'Maxis', 'Pinnacle', 'Xicat Interactive', 'Devolver Digital', 'Sunflowers', 'Strategy First', 'Lexicon Entertainment', 'Just Flight', 'GOA', 'Gearbox Software', 'Codemasters Online', '2D Boy', 'Graphsim Entertainment', 'DHM Interactive', 'Alternative Software', 'Flashpoint Games', 'Cloud Imperium Games Corporation', '5pb', 'Headup Games', 'Kool Kizz', 'Number None', 'Funbox Media', 'Mercury Games', 'Hudson Entertainment', 'Acquire', 'EA Games', 'White Park Bay Software', 'Hasbro Interactive', 'System 3', 'Scholastic Inc.', 'Fox Interactive', 'RTL', 'Black Label Games', 'Media Rings', 'Zushi Games', 'Russel', 'Nihon Falcom Corporation', 'Pacific Century Cyber Works', 'Wargaming.net', 'Home Entertainment Suppliers', 'TalonSoft', 'Tetris Online', 'Level 5', 'Activision Blizzard', 'ASCII Entertainment', 'Square', 'Square EA', 'SCS Software', 'Havas Interactive', 'Hello Games', 'inXile Entertainment', 'Groove Games', 'SNK', 'Myelin Media', 'Popcorn Arcade', 'Telegames', 'DSI Games', 'Sunsoft', 'O3 Entertainment', 'Phantom EFX', 'Cave', 'HMH Interactive', 'Valve', 'Ackkstudios', 'Aqua Plus', 'Bohemia Interactive', 'PM Studios', 'Illusion Softworks', 'O-Games', 'NDA Productions', 'Moss', 'Crytek', 'Funsta', 'NewKidCo']
#
# Categories in Developer with the lowest frequency (1): ['OfficeCreate', 'Nitro+', 'Splash Damage, The Coalition', 'Codo Games', 'WorkJam', 'LucasArts, BioWare', 'Valhalla Game Studios', 'Sonic Powered', 'EA DICE, Danger Close', 'Nikitova Games', 'Rebellion, Neversoft Entertainment', 'Ninja Studio', 'Dusenberry Martin Racing', 'Next Level Games, Nintendo', 'Blue Fang Games', 'Raylight Studios', 'Buka Entertainment, Targem Games', 'Doki Denki', 'Iron Lore Entertainment', 'Imagineer', 'Cranberry Production', 'EA Japan Studio', 'Headfirst Productions', 'Neon Studios', 'THQ, 1C, 1C Company', 'Dimps Corporation, Sonic Team', 'Studio Archcraft', 'Big Blue Box', 'AI', 'Brainbox Games', 'Hello Games', 'Cosmigo', 'Noise Factory', 'Foundation 9 Entertainment', 'Data Design Interactive', 'Telenet', 'Kheops Studio', 'Ready at Dawn, SCE Santa Monica', 'DreamRift', 'Vivendi Games', 'Toka', 'Realtime Worlds', 'Cunning Developments', 'Velez & Dubail', 'Mekensleep', 'Digital Leisure Inc.', 'EA Canada, Sensory Sweep', 'Gulti', 'Naughty Dog, Sony Bend', 'ECI', 'Indi', 'TimeGate Studios, Day 1 Studios', 'G1M2', 'The Code Monkeys', "Activision, Traveller's Tales", 'Smack Down Productions', 'Housemarque', 'BigPark', 'Metro3D', 'Digital Extremes, 2K Marin', 'Ambrella, The Pokemon Company', 'Flagship', 'Metropolis Software', 'Flagship, HAL Labs', 'Pinegrow', 'Sabertooth Games', 'IronNos Co.,Ltd.', 'DiP Interactive', 'Runtime', 'Silver Wish Games', 'GREZZO', 'Zoo Games', 'Synetic', 'Doublesix', 'Zed Two Limited', 'Powerhead Games', 'Rare Ltd., BigPark', 'Climax Studios', 'Enterbrain', 'Ubisoft, FunHouse', 'Human Soft', 'Ubisoft Barcelona', 'HAL Labs, Creatures Inc.', 'Box Clever Interactive', 'Leviathan Games', 'Goshow', 'Blue Planet Software', 'Vogster', 'Awesome Play Ltd.', 'Kodiak Interactive', '5000ft', 'Direct Action Games', 'Check Six Games', 'Runic Games', 'PLAYGROUND, Playground Games', 'Roxor Games', 'Interactive Brains', 'Team Soho', 'Liquid Dragon Studios', 'InterServ International', 'Mediascape, CUBETYPE', 'JoWooD Entertainment AG', 'Master Creating', 'Touchdown Entertainment', 'Turbine Inc.', 'Playstos Entertainment', 'Nvizzio Creations', 'Unigine Corp, Russia', 'Flagship Studios', 'ApolloSoft', 'Infogrames Sheffield', '1C:Ino-Co', 'Headup Games, Crenetic Studios', 'Tose Software', 'Pterodon', 'Trendy Entertainment', 'Beluga Computer', 'Stainless Steel Studios', 'Namco Bandai Games America', 'Gameness Art Software', 'Mindware Studios', 'EA Mythic', 'Atomic Planet Entertainment, Mud Duck Productions', 'MileStone Inc.', 'SEK Ost', 'The Tangentlemen', 'Multimedia Intelligence Transfer', 'Cryptic Studios', 'Edge Entertainment, Anima Project', 'Boxed Dream', 'Lead Pursuit', 'NATSUME ATARI Inc.', 'Punchline, Shirogumi', 'The Digital Lounge, Dino Dini', 'Retro Studios, Entertainment Analysis & Development Division', 'Strangelite', 'Deep Red', 'Tranji', 'EA Phenomic', 'Empty Clip Studios', 'TDK Mediactive', 'Headgate', 'Coffee Stain Studios', 'Activision Value', 'Boston Animation', 'React Games', 'Inferno Games', 'Katauri Interactive', 'High Moon Studios, Mercenary Technologies', 'Infinite Dreams, Paragon 5', 'Big Red Software', 'Fluid Studios', 'Atomic Games', 'Battlefront.com, 1C, 1C Company', 'Tecmo, Graphic Research', 'Spidersoft, Spiders', 'Autumn Moon', 'Vicious Cycle, Infinite Interactive', 'Cyan Worlds', 'GameCo', 'Babylon Software', 'Flying Lab Software', '1C, Ino-Co, 1C Company', 'Paradox Interactive', 'King of the Jungle', 'Tate Interactive', 'Elixir Studios', 'Compulsion Games', 'Camouflaj, LLC', 'Subterranean Games', 'DMA Design, Rockstar North', 'PuzzleKings', 'Games Farm', 'Crea-Tech', 'Volition Inc., CD Projekt Red Studio, CD Projekt, CD Projekt Localisation Centre', 'Nival Interactive', 'Office Create', 'Empire Interactive', 'Iridon Interactive AB', 'Nintendo, Namco Bandai Games', 'SCEA, Zindagi Games', 'Avalon Style', 'Blue 52', 'Rising Star Games', 'Nightlight Studios', 'EnjoyUp Games', 'SCEE, Zoe Mode', 'Reloaded Productions, R ...
#
# Categories in Rating with the lowest frequency (1): ['AO', 'K-A', 'RP']

# %%
## Thinking we can use this and then remove the other outliers

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## We are going to compare different features to global sales in order to see which ones are more relevant to predicting how well a game will sell globally

# %%
df.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6868.000000  6868.000000  6868.000000  6868.000000  6868.000000
# mean       2007.479470     0.366607     0.217076     0.058136     0.075491
# std           4.239552     0.677741     0.476903     0.242366     0.189461
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.380000     0.200000     0.010000     0.070000
# max        2016.000000     9.700000     6.420000     5.330000     7.530000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score    User_Count
# count   6868.000000   6868.000000   6868.000000  6868.000000   6868.000000
# mean       0.717496     70.308969     28.819744     7.189619    173.579936
# std        1.319016     13.744832     19.153100     1.431063    583.791215
# min        0.010000     20.000000      3.000000     0.500000      4.000000
# 25%        0.110000     62.000000     14.000000     6.500000     11.000000
# 50%        0.290000     72.000000     24.000000     7.500000     27.000000
# 75%        0.750000     80.000000     39.000000     8.200000     89.000000
# max       16.270000     98.000000    113.000000     9.600000  10665.000000

# %%
# List of categorical columns
categorical_columns = ["Name", "Platform", "Genre", "Publisher", "Developer", "Rating"]

# Value counts for each categorical column
for col in categorical_columns:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts())
# Out:
# Value counts for Name:
# Name
# LEGO Star Wars II: The Original Trilogy      8
# Madden NFL 07                                8
# Need for Speed: Most Wanted                  8
# Harry Potter and the Order of the Phoenix    7
# Tomb Raider: Legend                          7
#                                             ..
# Kengo: Master of Bushido                     1
# Advance Wars: Dual Strike                    1
# Auto Modellista                              1
# Tom Clancy's Ghost Recon 2: Summit Strike    1
# 15 Days                                      1
# Name: count, Length: 4411, dtype: int64
#
# Value counts for Platform:
# Platform
# PS2     1139
# X360     858
# PS3      771
# PC       686
# XB       564
# Wii      471
# DS       461
# PSP      390
# GC       348
# PS4      248
# GBA      237
# XOne     165
# 3DS      156
# PS       153
# PSV      118
# WiiU      89
# DC        14
# Name: count, dtype: int64
#
# Value counts for Genre:
# Genre
# Action          1640
# Sports           943
# Shooter          868
# Role-Playing     715
# Racing           582
# Platform         400
# Misc             382
# Fighting         379
# Simulation       302
# Strategy         277
# Adventure        262
# Puzzle           118
# Name: count, dtype: int64
#
# Value counts for Publisher:
# Publisher
# Electronic Arts                944
# Ubisoft                        498
# Activision                     492
# Sony Computer Entertainment    316
# THQ                            307
#                               ...
# NDA Productions                  1
# Moss                             1
# Crytek                           1
# Funsta                           1
# NewKidCo                         1
# Name: count, Length: 270, dtype: int64
#
# Value counts for Developer:
# Developer
# EA Canada                                 149
# EA Sports                                 142
# Capcom                                    126
# Ubisoft                                   103
# Konami                                     97
#                                          ...
# Felistella                                  1
# Netherock Ltd.                              1
# Interchannel                                1
# Warner Bros. Interactive Entertainment      1
# DTP Entertainment                           1
# Name: count, Length: 1301, dtype: int64
#
# Value counts for Rating:
# Rating
# T       2377
# E       2132
# M       1428
# E10+     928
# AO         1
# K-A        1
# RP         1
# Name: count, dtype: int64

# %% [markdown]
# ## How are global sales being impacted

# %%
# Visualize the impact of categorical columns on Global_Sales
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    df.groupby(col)["Global_Sales"].mean().sort_values(ascending=False).head(10).plot(
        kind="bar", color="skyblue", alpha=0.8
    )
    plt.title(f"Top 10 {col} Categories by Mean Global Sales", fontsize=16)
    plt.xlabel(col, fontsize=14)
    plt.ylabel("Mean Global Sales (in Millions)", fontsize=14)
    plt.xticks(rotation=45, ha="right", fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Getting the Stats for every feature

# %%
# List of numerical columns
numerical_columns = [
    "Year_of_Release",
    "NA_Sales",
    "EU_Sales",
    "JP_Sales",
    "Other_Sales",
    "Critic_Score",
    "Critic_Count",
    "User_Score",
    "User_Count",
]
# Descriptive statistics for numerical columns
print("\nSummary statistics for numerical columns:")
print(df[numerical_columns].describe())
# Out:
# Summary statistics for numerical columns:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6868.000000  6868.000000  6868.000000  6868.000000  6868.000000
# mean       2007.479470     0.366607     0.217076     0.058136     0.075491
# std           4.239552     0.677741     0.476903     0.242366     0.189461
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.380000     0.200000     0.010000     0.070000
# max        2016.000000     9.700000     6.420000     5.330000     7.530000
#
#        Critic_Score  Critic_Count   User_Score    User_Count
# count   6868.000000   6868.000000  6868.000000   6868.000000
# mean      70.308969     28.819744     7.189619    173.579936
# std       13.744832     19.153100     1.431063    583.791215
# min       20.000000      3.000000     0.500000      4.000000
# 25%       62.000000     14.000000     6.500000     11.000000
# 50%       72.000000     24.000000     7.500000     27.000000
# 75%       80.000000     39.000000     8.200000     89.000000
# max       98.000000    113.000000     9.600000  10665.000000

# %% [markdown]
# ## What do we do with this info  ? !!!!!!!!! below

# %%
# Visualize distributions of numerical columns using histplot
for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=30, color="orange", alpha=0.7)
    plt.title(f"Distribution of {col}", fontsize=16)
    plt.xlabel(col, fontsize=14)
    plt.ylabel("Density", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## what would we do about the outliers

# %%
# Compare each numerical column to Global_Sales using scatter plots
for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    plt.scatter(df[col], df["Global_Sales"], alpha=0.6, color="blue")
    plt.title(f"{col} vs Global Sales", fontsize=16)
    plt.xlabel(col, fontsize=14)
    plt.ylabel("Global Sales", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis="both", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## How persons scores compare to global sales

# %%
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Select the columns to normalize
numerical_columns = ['Global_Sales', 'Critic_Score', 'User_Score']

# Apply normalization
df_normalized = df.copy()  # Create a copy of the original DataFrame
df_normalized[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# View the normalized values
print(df_normalized[numerical_columns].describe())

# Scatter plot with normalized values
plt.figure(figsize=(10, 6))
plt.scatter(df_normalized['Critic_Score'], df_normalized['Global_Sales'], alpha=0.6, color='blue')
plt.title("Normalized Critic_Score vs Normalized Global Sales", fontsize=16)
plt.xlabel("Normalized Critic Score", fontsize=14)
plt.ylabel("Normalized Global Sales", fontsize=14)
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df_normalized['User_Score'], df_normalized['Global_Sales'], alpha=0.6, color='blue')
plt.title("Normalized User_Score vs Normalized Global Sales", fontsize=16)
plt.xlabel("Normalized User Score", fontsize=14)
plt.ylabel("Normalized Global Sales", fontsize=14)
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.show()
# Out:
#        Global_Sales  Critic_Score   User_Score
# count   6868.000000   6868.000000  6868.000000
# mean       0.043511      0.644987     0.735123
# std        0.081120      0.176216     0.157260
# min        0.000000      0.000000     0.000000
# 25%        0.006150      0.538462     0.659341
# 50%        0.017220      0.666667     0.769231
# 75%        0.045510      0.769231     0.846154
# max        1.000000      1.000000     1.000000

# %% [markdown]
# ## We use a correlation matrix in order to look for patterns | not sure how this helps probably would ask !!!!!!!!!!!

# %%
# Select only numerical columns
numerical_data = df.select_dtypes(include=["float64", "int64"])

# Compute correlation matrix
cor = numerical_data.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    cor,
    xticklabels=cor.columns,
    yticklabels=cor.columns,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
)
plt.title("Correlation Heatmap of Numerical Features", fontsize=16)
plt.show()

# %%
lower_quartile_critic_count = df["Critic_Count"].describe()["25%"]
lower_quartile_user_count = df["User_Count"].describe()["25%"]

df = df[df["Critic_Count"] >= lower_quartile_critic_count]
df = df[df["User_Count"] >= lower_quartile_user_count]

print(df.shape)
# Out:
# (4412, 16)

# %%
# print('df["Platform"].unique():', df["Platform"].unique())
# print('df["Genre"].unique():', df["Genre"].unique())
# print('df["Publisher"].unique():', df["Publisher"].unique().__len__())
# print('df["Developer"].unique():', df["Developer"].unique())
# print('df["Rating"].unique():', df["Rating"].unique())

# # df = pd.get_dummies(df, columns=["Platform", "Genre", "Rating"])
# # df.head()
#
# # rating AO - 1
# # rating K-A - 1

# %% [markdown]
# ## We are looking at how well different platforms compare to others

# %%
# Step 1: Group by Platform and Summarize Global Sales
platform_totals = df.groupby("Platform")["Global_Sales"].sum().sort_values(ascending=False)

# Step 2: Bar Chart for Total Global Sales by Platform
plt.figure(figsize=(12, 6))
platform_totals.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Total Global Sales by Platform", fontsize=16)
plt.xlabel("Platform", fontsize=14)
plt.ylabel("Total Global Sales (in millions)", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# Step 3: Scatter Plot for Each Platform
platforms = df["Platform"].unique()
